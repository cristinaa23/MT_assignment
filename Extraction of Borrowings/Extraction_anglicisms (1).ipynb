# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

#Load the two files: one containing the aligned original excel and the other with the translated csv.

df1 = pd.read_excel("/content/drive/MyDrive/MT assignment/MT_project.xlsx", names=['sentence_en', 'sentence_es'])
df2 = pd.read_csv("/content/drive/MyDrive/MT assignment/mt_translated_unido.csv", names=['sentence_mt'])

# %%
display(df1)
display(df2)
# Out:
#                                              sentence_en  \
# 0      SAN FRANCISCO – It has never been easy to have...
# 1      Lately, with gold prices up more than 300% ove...
# 2      Just last December, fellow economists Martin F...
# 3                                  Wouldn’t you know it?
# 4      Since their articles appeared, the price of go...
# ...                                                  ...
# 47612  But this does not hold true in all countries o...
# 47613  A more revealing-and distressing-indicator is ...
# 47614  Moreover, the first depressive episode occurs ...
# 47615  On the level of the wider population, the batt...
# 47616  But there is good news: for individual patient...
#
#                                              sentence_es
# 0      SAN FRANCISCO – Nunca ha resultado fácil soste...
# 1      Últimamente, con los precios del oro más de un...
# 2      Apenas en el pasado mes de diciembre, mis cole...
# 3                                          ¿Y saben qué?
# 4      Desde que aparecieron sus artículos, el precio...
# ...                                                  ...
# 47612  Pero esto no es así en todos los países o grup...
# 47613  Un indicador más revelador (y perturbador) es ...
# 47614  Más aún, el primer episodio depresivo ocurre e...
# 47615  A nivel de la población más general, la batall...
# 47616  Pero hay buenas noticias: para pacientes indiv...
#
# [47617 rows x 2 columns]
#                                              sentence_mt
# 0      SAN FRANCISCO  Nunca ha sido fácil tener una c...
# 1      Recientemente, con los precios del oro aumenta...
# 2      Solo en diciembre pasado, los economistas Mart...
# 3                                        ¿No lo sabrías?
# 4      Desde que aparecieron sus artículos, el precio...
# ...                                                  ...
# 47612  Pero esto no es cierto en todos los países o e...
# 47613  Un indicador más revelador y angustiante es qu...
# 47614  Además, el primer episodio depresivo ocurre en...
# 47615  En el ámbito de la población en general, la ba...
# 47616  Pero hay buenas noticias: para los pacientes c...
#
# [47617 rows x 1 columns]

# %%
#Add a column to have the MT sentences aligned with the original translation and the original english

df_joined = df1.join(df2)

# %%
display(df_joined)
# Out:
#                                              sentence_en  \
# 0      SAN FRANCISCO – It has never been easy to have...
# 1      Lately, with gold prices up more than 300% ove...
# 2      Just last December, fellow economists Martin F...
# 3                                  Wouldn’t you know it?
# 4      Since their articles appeared, the price of go...
# ...                                                  ...
# 47612  But this does not hold true in all countries o...
# 47613  A more revealing-and distressing-indicator is ...
# 47614  Moreover, the first depressive episode occurs ...
# 47615  On the level of the wider population, the batt...
# 47616  But there is good news: for individual patient...
#
#                                              sentence_es  \
# 0      SAN FRANCISCO – Nunca ha resultado fácil soste...
# 1      Últimamente, con los precios del oro más de un...
# 2      Apenas en el pasado mes de diciembre, mis cole...
# 3                                          ¿Y saben qué?
# 4      Desde que aparecieron sus artículos, el precio...
# ...                                                  ...
# 47612  Pero esto no es así en todos los países o grup...
# 47613  Un indicador más revelador (y perturbador) es ...
# 47614  Más aún, el primer episodio depresivo ocurre e...
# 47615  A nivel de la población más general, la batall...
# 47616  Pero hay buenas noticias: para pacientes indiv...
#
#                                              sentence_mt
# 0      SAN FRANCISCO  Nunca ha sido fácil tener una c...
# 1      Recientemente, con los precios del oro aumenta...
# 2      Solo en diciembre pasado, los economistas Mart...
# 3                                        ¿No lo sabrías?
# 4      Desde que aparecieron sus artículos, el precio...
# ...                                                  ...
# 47612  Pero esto no es cierto en todos los países o e...
# 47613  Un indicador más revelador y angustiante es qu...
# 47614  Además, el primer episodio depresivo ocurre en...
# 47615  En el ámbito de la población en general, la ba...
# 47616  Pero hay buenas noticias: para los pacientes c...
#
# [47617 rows x 3 columns]

# %%
#Save the dataframe as a csv
df_joined.to_csv('/content/drive/MyDrive/MT assignment/mt_translated_all.csv', index=False, header=None)

# %%
! pip install torch==1.10.1+cu102 torchtext==0.11.1 -f https://download.pytorch.org/whl/torch_stable.html
! pip install setuptools==59.5.0 
! pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.10.1+cu102 (from versions: 1.11.0, 1.11.0+cpu, 1.11.0+cu102, 1.11.0+cu113, 1.11.0+cu115, 1.11.0+rocm4.3.1, 1.11.0+rocm4.5.2, 1.12.0, 1.12.0+cpu, 1.12.0+cu102, 1.12.0+cu113, 1.12.0+cu116, 1.12.0+rocm5.0, 1.12.0+rocm5.1.1, 1.12.1, 1.12.1+cpu, 1.12.1+cu102, 1.12.1+cu113, 1.12.1+cu116, 1.12.1+rocm5.0, 1.12.1+rocm5.1.1, 1.13.0, 1.13.0+cpu, 1.13.0+cu116, 1.13.0+cu117, 1.13.0+cu117.with.pypi.cudnn, 1.13.0+rocm5.1.1, 1.13.0+rocm5.2, 1.13.1, 1.13.1+cpu, 1.13.1+cu116, 1.13.1+cu117, 1.13.1+cu117.with.pypi.cudnn, 1.13.1+rocm5.1.1, 1.13.1+rocm5.2, 2.0.0, 2.0.0+cpu, 2.0.0+cpu.cxx11.abi, 2.0.0+cu117, 2.0.0+cu117.with.pypi.cudnn, 2.0.0+cu118, 2.0.0+rocm5.3, 2.0.0+rocm5.4.2, 2.0.1+cpu, 2.0.1+cpu.cxx11.abi, 2.0.1+cu117, 2.0.1+cu117.with.pypi.cudnn, 2.0.1+cu118, 2.0.1+rocm5.3, 2.0.1+rocm5.4.2)
# ERROR: No matching distribution found for torch==1.10.1+cu102
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: setuptools==59.5.0 in /usr/local/lib/python3.10/dist-packages (59.5.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.28.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
#Activate GPU for pipeline use

import torch
device = 0 if torch.cuda.is_available() else -1

# %%
#Convert Spanish sentences to a list
es_sent = df_joined['sentence_es'].to_list()

# %%
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer

#Load the tokenizer, model and pipeline
tokenizer = AutoTokenizer.from_pretrained("lirondos/anglicisms-spanish-mbert")
model = AutoModelForTokenClassification.from_pretrained("lirondos/anglicisms-spanish-mbert")
nlp = pipeline("ner", model=model, tokenizer=tokenizer, device=device)

example = example = "Buscamos data scientist para proyecto de machine learning."

borrowings = nlp(example)

print(borrowings)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'B-ENG', 'score': 0.99480647, 'index': 3, 'word': 'data', 'start': 9, 'end': 13}, {'entity': 'I-ENG', 'score': 0.994532, 'index': 4, 'word': 'scientist', 'start': 14, 'end': 23}, {'entity': 'B-ENG', 'score': 0.99654704, 'index': 8, 'word': 'machine', 'start': 41, 'end': 48}, {'entity': 'I-ENG', 'score': 0.9956513, 'index': 9, 'word': 'learning', 'start': 49, 'end': 57}]

# %%
from collections import defaultdict

#Define a default dict to store the output of the model. The keys are the words and the value of the dictionary the frequency of the term.
loanwords = defaultdict(int)

for borrow in borrowings:
  word = borrow['word'].lower()
  loanwords[word]+= 1

print(loanwords)
# Out:
# defaultdict(<class 'int'>, {'data': 1, 'scientist': 1, 'machine': 1, 'learning': 1})

# %%
import pandas as pd
from collections import defaultdict
df = pd.read_csv("/content/drive/MyDrive/MT assignment/mt_translated_all.csv", names=['sentence_en', 'sentence_es', 'sentence_mt'])

display(df)
# Out:
#                                              sentence_en  \
# 0      SAN FRANCISCO – It has never been easy to have...
# 1      Lately, with gold prices up more than 300% ove...
# 2      Just last December, fellow economists Martin F...
# 3                                  Wouldn’t you know it?
# 4      Since their articles appeared, the price of go...
# ...                                                  ...
# 47612  But this does not hold true in all countries o...
# 47613  A more revealing-and distressing-indicator is ...
# 47614  Moreover, the first depressive episode occurs ...
# 47615  On the level of the wider population, the batt...
# 47616  But there is good news: for individual patient...
#
#                                              sentence_es  \
# 0      SAN FRANCISCO – Nunca ha resultado fácil soste...
# 1      Últimamente, con los precios del oro más de un...
# 2      Apenas en el pasado mes de diciembre, mis cole...
# 3                                          ¿Y saben qué?
# 4      Desde que aparecieron sus artículos, el precio...
# ...                                                  ...
# 47612  Pero esto no es así en todos los países o grup...
# 47613  Un indicador más revelador (y perturbador) es ...
# 47614  Más aún, el primer episodio depresivo ocurre e...
# 47615  A nivel de la población más general, la batall...
# 47616  Pero hay buenas noticias: para pacientes indiv...
#
#                                              sentence_mt
# 0      SAN FRANCISCO  Nunca ha sido fácil tener una c...
# 1      Recientemente, con los precios del oro aumenta...
# 2      Solo en diciembre pasado, los economistas Mart...
# 3                                        ¿No lo sabrías?
# 4      Desde que aparecieron sus artículos, el precio...
# ...                                                  ...
# 47612  Pero esto no es cierto en todos los países o e...
# 47613  Un indicador más revelador y angustiante es qu...
# 47614  Además, el primer episodio depresivo ocurre en...
# 47615  En el ámbito de la población en general, la ba...
# 47616  Pero hay buenas noticias: para los pacientes c...
#
# [47617 rows x 3 columns]

# %%
from collections import defaultdict

def borrowings(df, ver):
    loanwords = defaultdict(int)
    count = 0
    for idx, row in df.iterrows():
        borrow_list = []
        borrowing = nlp(row['sentence_'+ver])
        for borrow in borrowing:
            word = borrow['word']
            borrow_list.append(word)
            loanwords[word] += 1
            count += 1
        if len(borrow_list) > 0:
            df.at[idx, ver +' Borrowings'] = str(borrow_list).replace("[","").replace("]","")
        else:
            df.at[idx, ver +' Borrowings'] = 'O'
    print(f"Number of borrowings in sentence_{ver}: {count}")
    df_loan2 = pd.DataFrame.from_dict(loanwords, orient='index')
    df_loan2.to_csv(f'/content/drive/MyDrive/MT assignment/loan_{ver}.csv')
    return df

version = ['es', 'mt']


for ver in version:
  new_df2 = borrowings(df, ver)


new_df2.to_csv(f'/content/drive/MyDrive/MT assignment/loans_all.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Number of borrowings in sentence_es: 9577
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Number of borrowings in sentence_mt: 9400

# %%
display(new_df2)
# Out:
#                                              sentence_en  \
# 0      SAN FRANCISCO – It has never been easy to have...
# 1      Lately, with gold prices up more than 300% ove...
# 2      Just last December, fellow economists Martin F...
# 3                                  Wouldn’t you know it?
# 4      Since their articles appeared, the price of go...
# ...                                                  ...
# 47612  But this does not hold true in all countries o...
# 47613  A more revealing-and distressing-indicator is ...
# 47614  Moreover, the first depressive episode occurs ...
# 47615  On the level of the wider population, the batt...
# 47616  But there is good news: for individual patient...
#
#                                              sentence_es  \
# 0      SAN FRANCISCO – Nunca ha resultado fácil soste...
# 1      Últimamente, con los precios del oro más de un...
# 2      Apenas en el pasado mes de diciembre, mis cole...
# 3                                          ¿Y saben qué?
# 4      Desde que aparecieron sus artículos, el precio...
# ...                                                  ...
# 47612  Pero esto no es así en todos los países o grup...
# 47613  Un indicador más revelador (y perturbador) es ...
# 47614  Más aún, el primer episodio depresivo ocurre e...
# 47615  A nivel de la población más general, la batall...
# 47616  Pero hay buenas noticias: para pacientes indiv...
#
#                                              sentence_mt es Borrowings  \
# 0      SAN FRANCISCO  Nunca ha sido fácil tener una c...             O
# 1      Recientemente, con los precios del oro aumenta...             O
# 2      Solo en diciembre pasado, los economistas Mart...             O
# 3                                        ¿No lo sabrías?             O
# 4      Desde que aparecieron sus artículos, el precio...             O
# ...                                                  ...           ...
# 47612  Pero esto no es cierto en todos los países o e...             O
# 47613  Un indicador más revelador y angustiante es qu...             O
# 47614  Además, el primer episodio depresivo ocurre en...             O
# 47615  En el ámbito de la población en general, la ba...             O
# 47616  Pero hay buenas noticias: para los pacientes c...             O
#
#       mt Borrowings
# 0                 O
# 1                 O
# 2                 O
# 3                 O
# 4                 O
# ...             ...
# 47612             O
# 47613             O
# 47614             O
# 47615             O
# 47616             O
#
# [47617 rows x 5 columns]

# %%
#Define a default dict to store the output of the model. The keys are the words and the value of the dictionary the frequency of the term.

mt_sent = df_joined['sentence_mt'].to_list()
loanwords2 = defaultdict(int)

for sentence in mt_sent:
  borrowing = nlp(sentence)
  for borrow in borrowing:
    word = borrow['word']
    loanwords2[word]+= 1
print(loanwords2)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# defaultdict(<class 'int'>, {'do': 13, '##w': 10, 'fr': 1, '##eak': 1, 'record': 5, 'vision': 132, 'os': 3, '##t': 32, '##politik': 7, 'le': 25, '##hman': 20, 'brothers': 21, 'yo': 164, '##rk': 154, 'wins': 12, '##ton': 161, 'church': 36, 'that': 25, '##cher': 22, 'supervision': 44, 'wol': 20, '##f': 14, 'ei': 2, '##green': 2, '##chen': 2, 'mos': 2, '##co': 46, 'star': 5, 'city': 7, '##sk': 1, 'space': 4, '-': 104, 'x': 8, 'je': 8, '##ff': 8, 'blue': 5, 'origin': 1, 'gr': 2, '##eas': 1, '##on': 7, 'mark': 14, 'shut': 1, '##tle': 7, 'tha': 9, 'adventure': 3, '##ft': 37, 'intention': 1, 'software': 54, 'google': 9, 'prince': 7, 'television': 41, 't': 23, '##tip': 3, 'bara': 66, 'was': 130, '##hing': 127, 'bear': 3, 'ster': 3, 'tr': 344, 'areas': 52, 'dona': 7, '##ld': 2, '##ump': 354, 'decision': 247, 'bl': 44, '##air': 37, 'ang': 1, '##st': 2, 'world': 7, 'trade': 9, 'center': 7, 'portfolio': 1, '##al': 1, 'union': 25, '##ill': 37, 'ger': 8, 'ton': 7, 'west': 11, '##mins': 7, 'deficit': 21, 'hon': 40, '##g': 44, 'kong': 45, 'hy': 3, '##man': 22, 'min': 2, '##sky': 1, '##mpet': 3, 'expansion': 30, 'cam': 73, '##bridge': 71, 'hen': 3, 'lo': 36, '##uis': 3, 'skip': 1, 'gates': 27, 'c': 67, '##row': 4, '##ley': 6, 'hardware': 9, '##zy': 8, 'bli': 3, '##ng': 21, 'sand': 7, '##ers': 17, '##l': 3, 'mani': 1, '##sh': 2, '##bhar': 1, '##wal': 1, 'team': 1, '##lea': 8, 'fl': 4, '##ip': 5, '##kar': 1, 'american': 1, 'economic': 4, 'review': 7, 'ant': 1, '##hon': 1, '##y': 20, 'bu': 17, '##rge': 2, '##ss': 6, 'clock': 2, '##work': 2, 'orange': 2, 'opinion': 1, 's': 42, '##mitt': 1, 'co': 9, 'gaz': 3, '##pro': 3, '##m': 37, 'trots': 1, '##ky': 2, 'mar': 4, '##gare': 2, 'new': 34, '##rker':